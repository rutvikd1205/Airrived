# %%
import pandas as pd
import re
import json

# %%
techniques = pd.read_html('https://attack.mitre.org/techniques/enterprise/')
tech_df = techniques[0]
tech_df
# Out:
#         ID   ID.1                                Name  \
# 0    T1548  T1548   Abuse Elevation Control Mechanism
# 1      NaN   .001                   Setuid and Setgid
# 2      NaN   .002         Bypass User Account Control
# 3      NaN   .003               Sudo and Sudo Caching
# 4      NaN   .004      Elevated Execution with Prompt
# ..     ...    ...                                 ...
# 632    NaN   .001                  Dead Drop Resolver
# 633    NaN   .002         Bidirectional Communication
# 634    NaN   .003               One-Way Communication
# 635  T1047  T1047  Windows Management Instrumentation
# 636  T1220  T1220               XSL Script Processing
#
#                                            Description
# 0    Adversaries may circumvent mechanisms designed...
# 1    An adversary may abuse configurations where an...
# 2    Adversaries may bypass UAC mechanisms to eleva...
# 3    Adversaries may perform sudo caching and/or us...
# 4    Adversaries may leverage the AuthorizationExec...
# ..                                                 ...
# 632  Adversaries may use an existing, legitimate ex...
# 633  Adversaries may use an existing, legitimate ex...
# 634  Adversaries may use an existing, legitimate ex...
# 635  Adversaries may abuse Windows Management Instr...
# 636  Adversaries may bypass application control and...
#
# [637 rows x 4 columns]

# %%
techniques_dict = {}

current_technique = None

for index, row in tech_df.iterrows():
    if not pd.isna(row['ID']):

        current_technique = row['Name']
        techniques_dict[current_technique] = {'sub-techniques': []}
    else:

        if current_technique is not None:
            techniques_dict[current_technique]['sub-techniques'].append(row['Name'])

# %%
techniques_dict
# Out:
# {'Abuse Elevation Control Mechanism': {'sub-techniques': ['Setuid and Setgid',
#    'Bypass User Account Control',
#    'Sudo and Sudo Caching',
#    'Elevated Execution with Prompt',
#    'Temporary Elevated Cloud Access',
#    'TCC Manipulation']},
#  'Access Token Manipulation': {'sub-techniques': ['Token Impersonation/Theft',
#    'Create Process with Token',
#    'Make and Impersonate Token',
#    'Parent PID Spoofing',
#    'SID-History Injection']},
#  'Account Access Removal': {'sub-techniques': []},
#  'Account Discovery': {'sub-techniques': ['Local Account',
#    'Domain Account',
#    'Email Account',
#    'Cloud Account']},
#  'Account Manipulation': {'sub-techniques': ['Additional Cloud Credentials',
#    'Additional Email Delegate Permissions',
#    'Additional Cloud Roles',
#    'SSH Authorized Keys',
#    'Device Registration',
#    'Additional Container Cluster Roles']},
#  'Acquire Access': {'sub-techniques': []},
#  'Acquire Infrastructure': {'sub-techniques': ['Domains',
#    'DNS Server',
#    'Virtual Private Server',
#    'Server',
#    'Botnet',
#    'Web Services',
#    'Serverless',
#    'Malvertising']},
#  'Active Scanning': {'sub-techniques': ['Scanning IP Blocks',
#    'Vulnerability Scanning',
#    'Wordlist Scanning']},
#  'Adversary-in-the-Middle': {'sub-techniques': ['LLMNR/NBT-NS Poisoning and SMB Relay',
#    'ARP Cache Poisoning',
#    'DHCP Spoofing']},
#  'Application Layer Protocol': {'sub-techniques': ['Web Protocols',
#    'File Transfer Protocols',
#    'Mail Protocols',
#    'DNS']},
#  'Application Window Discovery': {'sub-techniques': []},
#  'Archive Collected Data': {'sub-techniques': ['Archive via Utility',
#    'Archive via Library',
#    'Archive via Custom Method']},
#  'Audio Capture': {'sub-techniques': []},
#  'Automated Collection': {'sub-techniques': []},
#  'Automated Exfiltration': {'sub-techniques': ['Traffic Duplication']},
#  'BITS Jobs': {'sub-techniques': []},
#  'Boot or Logon Autostart Execution': {'sub-techniques': ['Registry Run Keys / Startup Folder',
#    'Authentication Package',
#    'Time Providers',
#    'Winlogon Helper DLL',
#    'Security Support Provider',
#    'Kernel Modules and Extensions',
#    'Re-opened Applications',
#    'LSASS Driver',
#    'Shortcut Modification',
#    'Port Monitors',
#    'Print Processors',
#    'XDG Autostart Entries',
#    'Active Setup',
#    'Login Items']},
#  'Boot or Logon Initialization Scripts': {'sub-techniques': ['Logon Script (Windows)',
#    'Login Hook',
#    'Network Logon Script',
#    'RC Scripts',
#    'Startup Items']},
#  'Browser Extensions': {'sub-techniques': []},
#  'Browser Information Discovery': {'sub-techniques': []},
#  'Browser Session Hijacking': {'sub-techniques': []},
#  'Brute Force': {'sub-techniques': ['Password Guessing',
#    'Password Cracking',
#    'Password Spraying',
#    'Credential Stuffing']},
#  'Build Image on Host': {'sub-techniques': []},
#  'Clipboard Data': {'sub-techniques': []},
#  'Cloud Administration Command': {'sub-techniques': []},
#  'Cloud Infrastructure Discovery': {'sub-techniques': []},
#  'Cloud Service Dashboard': {'sub-techniques': []},
#  'Cloud Service Discovery': {'sub-techniques': []},
#  'Cloud Storage Object Discovery': {'sub-techniques': []},
#  'Command and Scripting Interpreter': {'sub-techniques': ['PowerShell',
#    'AppleScript',
#    'Windows Command Shell',
#    'Unix Shell',
#    'Visual Basic',
#    'Python',
#    'JavaScript',
#    'Network Device CLI',
#    'Cloud API',
#    'AutoHotKey & AutoIT']},
#  'Communication Through Removable Media': {'sub-techniques': []},
#  'Compromise Accounts': {'sub-techniques': ['Social Media Accounts',
#    'Email Accounts',
#    'Cloud Accounts']},
#  'Compromise Host Software Binary': {'sub-techniques': []},
#  'Compromise Infrastructure': {'sub-techniques': ['Domains',
#    'DNS Server',
#    'Virtual Private Server',
#    'Server',
#    'Botnet',
#    'Web Services',
#    'Serverless',
#    'Network Devices']},
#  'Container Administration Command': {'sub-techniques': []},
#  'Container and Resource Discovery': {'sub-techniques': []},
#  'Content Injection': {'sub-techniques': []},
#  'Create Account': {'sub-techniques': ['Local Account',
#    'Domain Account',
#    'Cloud Account']},
#  'Create or Modify System Process': {'sub-techniques': ['Launch Agent',
#    'Systemd Service',
#    'Windows Service',
#    'Launch Daemon',
#    'Container Service']},
#  'Credentials from Password Stores': {'sub-techniques': ['Keychain',
#    'Securityd Memory',
#    'Credentials from Web Browsers',
#    'Windows Credential Manager',
#    'Password Managers',
#    'Cloud Secrets Management Stores']},
#  'Data Destruction': {'sub-techniques': []},
#  'Data Encoding': {'sub-techniques': ['Standard Encoding',
#    'Non-Standard Encoding']},
#  'Data Encrypted for Impact': {'sub-techniques': []},
#  'Data from Cloud Storage': {'sub-techniques': []},
#  'Data from Configuration Repository': {'sub-techniques': ['SNMP (MIB Dump)',
#    'Network Device Configuration Dump']},
#  'Data from Information Repositories': {'sub-techniques': ['Confluence',
#    'Sharepoint',
#    'Code Repositories']},
#  'Data from Local System': {'sub-techniques': []},
#  'Data from Network Shared Drive': {'sub-techniques': []},
#  'Data from Removable Media': {'sub-techniques': []},
#  'Data Manipulation': {'sub-techniques': ['Stored Data Manipulation',
#    'Transmitted Data Manipulation',
#    'Runtime Data Manipulation']},
#  'Data Obfuscation': {'sub-techniques': ['Junk Data',
#    'Steganography',
#    'Protocol Impersonation']},
#  'Data Staged': {'sub-techniques': ['Local Data Staging',
#    'Remote Data Staging']},
#  'Data Transfer Size Limits': {'sub-techniques': []},
#  'Debugger Evasion': {'sub-techniques': []},
#  'Defacement': {'sub-techniques': ['Internal Defacement',
#    'External Defacement']},
#  'Deobfuscate/Decode Files or Information': {'sub-techniques': []},
#  'Deploy Container': {'sub-techniques': []},
#  'Develop Capabilities': {'sub-techniques': ['Malware',
#    'Code Signing Certificates',
#    'Digital Certificates',
#    'Exploits']},
#  'Device Driver Discovery': {'sub-techniques': []},
#  'Direct Volume Access': {'sub-techniques': []},
#  'Disk Wipe': {'sub-techniques': ['Disk Content Wipe', 'Disk Structure Wipe']},
#  'Domain or Tenant Policy Modification': {'sub-techniques': ['Group Policy Modification',
#    'Trust Modification']},
#  'Domain Trust Discovery': {'sub-techniques': []},
#  'Drive-by Compromise': {'sub-techniques': []},
#  'Dynamic Resolution': {'sub-techniques': ['Fast Flux DNS',
#    'Domain Generation Algorithms',
#    'DNS Calculation']},
#  'Email Collection': {'sub-techniques': ['Local Email Collection',
#    'Remote Email Collection',
#    'Email Forwarding Rule']},
#  'Encrypted Channel': {'sub-techniques': ['Symmetric Cryptography',
#    'Asymmetric Cryptography']},
#  'Endpoint Denial of Service': {'sub-techniques': ['OS Exhaustion Flood',
#    'Service Exhaustion Flood',
#    'Application Exhaustion Flood',
#    'Application or System Exploitation']},
#  'Escape to Host': {'sub-techniques': []},
#  'Establish Accounts': {'sub-techniques': ['Social Media Accounts',
#    'Email Accounts',
#    'Cloud Accounts']},
#  'Event Triggered Execution': {'sub-techniques': ['Change Default File Association',
#    'Screensaver',
#    'Windows Management Instrumentation Event Subscription',
#    'Unix Shell Configuration Modification',
#    'Trap',
#    'LC_LOAD_DYLIB Addition',
#    'Netsh Helper DLL',
#    'Accessibility Features',
#    'AppCert DLLs',
#    'AppInit DLLs',
#    'Application Shimming',
#    'Image File Execution Options Injection',
#    'PowerShell Profile',
#    'Emond',
#    'Component Object Model Hijacking',
#    'Installer Packages']},
#  'Execution Guardrails': {'sub-techniques': ['Environmental Keying']},
#  'Exfiltration Over Alternative Protocol': {'sub-techniques': ['Exfiltration Over Symmetric Encrypted Non-C2 Protocol',
#    'Exfiltration Over Asymmetric Encrypted Non-C2 Protocol',
#    'Exfiltration Over Unencrypted Non-C2 Protocol']},
#  'Exfiltration Over C2 Channel': {'sub-techniques': []},
#  'Exfiltration Over Other Network Medium': {'sub-techniques': ['Exfiltration Over Bluetooth']},
#  'Exfiltration Over Physical Medium': {'sub-techniques': ['Exfiltration over USB']},
#  'Exfiltration Over Web Service': {'sub-techniques': ['Exfiltration to Code Repository',
#    'Exfiltration to Cloud Storage',
#    'Exfiltration to Text Storage Sites',
#    'Exfiltration Over Webhook']},
#  'Exploit Public-Facing Application': {'sub-techniques': []},
#  'Exploitation for Client Execution': {'sub-techniques': []},
#  'Exploitation for Credential Access': {'sub-techniques': []},
#  'Exploitation for Defense Evasion': {'sub-techniques': []},
#  'Exploitation for Privilege Escalation': {'sub-techniques': []},
#  'Exploitation of Remote Services': {'sub-techniques': []},
#  'External Remote Services': {'sub-techniques': []},
#  'Fallback Channels': {'sub-techniques': []},
#  'File and Directory Discovery': {'sub-techniques': []},
#  'File and Directory Permissions Modification': {'sub-techniques': ['Windows File and Directory Permissions Modification',
#    'Linux and Mac File and Directory Permissions Modification']},
#  'Financial Theft': {'sub-techniques': []},
#  'Firmware Corruption': {'sub-techniques': []},
#  'Forced Authentication': {'sub-techniques': []},
#  'Forge Web Credentials': {'sub-techniques': ['Web Cookies', 'SAML Tokens']},
#  'Gather Victim Host Information': {'sub-techniques': ['Hardware',
#    'Software',
#    'Firmware',
#    'Client Configurations']},
#  'Gather Victim Identity Information': {'sub-techniques': ['Credentials',
#    'Email Addresses',
#    'Employee Names']},
#  'Gather Victim Network Information': {'sub-techniques': ['Domain Properties',
#    'DNS',
#    'Network Trust Dependencies',
#    'Network Topology',
#    'IP Addresses',
#    'Network Security Appliances']},
#  'Gather Victim Org Information': {'sub-techniques': ['Determine Physical Locations',
#    'Business Relationships',
#    'Identify Business Tempo',
#    'Identify Roles']},
#  'Group Policy Discovery': {'sub-techniques': []},
#  'Hardware Additions': {'sub-techniques': []},
#  'Hide Artifacts': {'sub-techniques': ['Hidden Files and Directories',
#    'Hidden Users',
#    'Hidden Window',
#    'NTFS File Attributes',
#    'Hidden File System',
#    'Run Virtual Instance',
#    'VBA Stomping',
#    'Email Hiding Rules',
#    'Resource Forking',
#    'Process Argument Spoofing',
#    'Ignore Process Interrupts',
#    'File/Path Exclusions']},
#  'Hide Infrastructure': {'sub-techniques': []},
#  'Hijack Execution Flow': {'sub-techniques': ['DLL Search Order Hijacking',
#    'DLL Side-Loading',
#    'Dylib Hijacking',
#    'Executable Installer File Permissions Weakness',
#    'Dynamic Linker Hijacking',
#    'Path Interception by PATH Environment Variable',
#    'Path Interception by Search Order Hijacking',
#    'Path Interception by Unquoted Path',
#    'Services File Permissions Weakness',
#    'Services Registry Permissions Weakness',
#    'COR_PROFILER',
#    'KernelCallbackTable',
#    'AppDomainManager']},
#  'Impair Defenses': {'sub-techniques': ['Disable or Modify Tools',
#    'Disable Windows Event Logging',
#    'Impair Command History Logging',
#    'Disable or Modify System Firewall',
#    'Indicator Blocking',
#    'Disable or Modify Cloud Firewall',
#    'Disable or Modify Cloud Logs',
#    'Safe Mode Boot',
#    'Downgrade Attack',
#    'Spoof Security Alerting',
#    'Disable or Modify Linux Audit System']},
#  'Impersonation': {'sub-techniques': []},
#  'Implant Internal Image': {'sub-techniques': []},
#  'Indicator Removal': {'sub-techniques': ['Clear Windows Event Logs',
#    'Clear Linux or Mac System Logs',
#    'Clear Command History',
#    'File Deletion',
#    'Network Share Connection Removal',
#    'Timestomp',
#    'Clear Network Connection History and Configurations',
#    'Clear Mailbox Data',
#    'Clear Persistence']},
#  'Indirect Command Execution': {'sub-techniques': []},
#  'Ingress Tool Transfer': {'sub-techniques': []},
#  'Inhibit System Recovery': {'sub-techniques': []},
#  'Input Capture': {'sub-techniques': ['Keylogging',
#    'GUI Input Capture',
#    'Web Portal Capture',
#    'Credential API Hooking']},
#  'Inter-Process Communication': {'sub-techniques': ['Component Object Model',
#    'Dynamic Data Exchange',
#    'XPC Services']},
#  'Internal Spearphishing': {'sub-techniques': []},
#  'Lateral Tool Transfer': {'sub-techniques': []},
#  'Log Enumeration': {'sub-techniques': []},
#  'Masquerading': {'sub-techniques': ['Invalid Code Signature',
#    'Right-to-Left Override',
#    'Rename System Utilities',
#    'Masquerade Task or Service',
#    'Match Legitimate Name or Location',
#    'Space after Filename',
#    'Double File Extension',
#    'Masquerade File Type',
#    'Break Process Trees']},
#  'Modify Authentication Process': {'sub-techniques': ['Domain Controller Authentication',
#    'Password Filter DLL',
#    'Pluggable Authentication Modules',
#    'Network Device Authentication',
#    'Reversible Encryption',
#    'Multi-Factor Authentication',
#    'Hybrid Identity',
#    'Network Provider DLL',
#    'Conditional Access Policies']},
#  'Modify Cloud Compute Infrastructure': {'sub-techniques': ['Create Snapshot',
#    'Create Cloud Instance',
#    'Delete Cloud Instance',
#    'Revert Cloud Instance',
#    'Modify Cloud Compute Configurations']},
#  'Modify Registry': {'sub-techniques': []},
#  'Modify System Image': {'sub-techniques': ['Patch System Image',
#    'Downgrade System Image']},
#  'Multi-Factor Authentication Interception': {'sub-techniques': []},
#  'Multi-Factor Authentication Request Generation': {'sub-techniques': []},
#  'Multi-Stage Channels': {'sub-techniques': []},
#  'Native API': {'sub-techniques': []},
#  'Network Boundary Bridging': {'sub-techniques': ['Network Address Translation Traversal']},
#  'Network Denial of Service': {'sub-techniques': ['Direct Network Flood',
#    'Reflection Amplification']},
#  'Network Service Discovery': {'sub-techniques': []},
#  'Network Share Discovery': {'sub-techniques': []},
#  'Network Sniffing': {'sub-techniques': []},
#  'Non-Application Layer Protocol': {'sub-techniques': []},
#  'Non-Standard Port': {'sub-techniques': []},
#  'Obfuscated Files or Information': {'sub-techniques': ['Binary Padding',
#    'Software Packing',
#    'Steganography',
#    'Compile After Delivery',
#    'Indicator Removal from Tools',
#    'HTML Smuggling',
#    'Dynamic API Resolution',
#    'Stripped Payloads',
#    'Embedded Payloads',
#    'Command Obfuscation',
#    'Fileless Storage',
#    'LNK Icon Smuggling',
#    'Encrypted/Encoded File']},
#  'Obtain Capabilities': {'sub-techniques': ['Malware',
#    'Tool',
#    'Code Signing Certificates',
#    'Digital Certificates',
#    'Exploits',
#    'Vulnerabilities',
#    'Artificial Intelligence']},
#  'Office Application Startup': {'sub-techniques': ['Office Template Macros',
#    'Office Test',
#    'Outlook Forms',
#    'Outlook Home Page',
#    'Outlook Rules',
#    'Add-ins']},
#  'OS Credential Dumping': {'sub-techniques': ['LSASS Memory',
#    'Security Account Manager',
#    'NTDS',
#    'LSA Secrets',
#    'Cached Domain Credentials',
#    'DCSync',
#    'Proc Filesystem',
#    '/etc/passwd and /etc/shadow']},
#  'Password Policy Discovery': {'sub-techniques': []},
#  'Peripheral Device Discovery': {'sub-techniques': []},
#  'Permission Groups Discovery': {'sub-techniques': ['Local Groups',
#    'Domain Groups',
#    'Cloud Groups']},
#  'Phishing': {'sub-techniques': ['Spearphishing Attachment',
#    'Spearphishing Link',
#    'Spearphishing via Service',
#    'Spearphishing Voice']},
#  'Phishing for Information': {'sub-techniques': ['Spearphishing Service',
#    'Spearphishing Attachment',
#    'Spearphishing Link',
#    'Spearphishing Voice']},
#  'Plist File Modification': {'sub-techniques': []},
#  'Power Settings': {'sub-techniques': []},
#  'Pre-OS Boot': {'sub-techniques': ['System Firmware',
#    'Component Firmware',
#    'Bootkit',
#    'ROMMONkit',
#    'TFTP Boot']},
#  'Process Discovery': {'sub-techniques': []},
#  'Process Injection': {'sub-techniques': ['Dynamic-link Library Injection',
#    'Portable Executable Injection',
#    'Thread Execution Hijacking',
#    'Asynchronous Procedure Call',
#    'Thread Local Storage',
#    'Ptrace System Calls',
#    'Proc Memory',
#    'Extra Window Memory Injection',
#    'Process Hollowing',
#    'Process Doppelgänging',
#    'VDSO Hijacking',
#    'ListPlanting']},
#  'Protocol Tunneling': {'sub-techniques': []},
#  'Proxy': {'sub-techniques': ['Internal Proxy',
#    'External Proxy',
#    'Multi-hop Proxy',
#    'Domain Fronting']},
#  'Query Registry': {'sub-techniques': []},
#  'Reflective Code Loading': {'sub-techniques': []},
#  'Remote Access Software': {'sub-techniques': []},
#  'Remote Service Session Hijacking': {'sub-techniques': ['SSH Hijacking',
#    'RDP Hijacking']},
#  'Remote Services': {'sub-techniques': ['Remote Desktop Protocol',
#    'SMB/Windows Admin Shares',
#    'Distributed Component Object Model',
#    'SSH',
#    'VNC',
#    'Windows Remote Management',
#    'Cloud Services',
#    'Direct Cloud VM Connections']},
#  'Remote System Discovery': {'sub-techniques': []},
#  'Replication Through Removable Media': {'sub-techniques': []},
#  'Resource Hijacking': {'sub-techniques': []},
#  'Rogue Domain Controller': {'sub-techniques': []},
#  'Rootkit': {'sub-techniques': []},
#  'Scheduled Task/Job': {'sub-techniques': ['At',
#    'Cron',
#    'Scheduled Task',
#    'Systemd Timers',
#    'Container Orchestration Job']},
#  'Scheduled Transfer': {'sub-techniques': []},
#  'Screen Capture': {'sub-techniques': []},
#  'Search Closed Sources': {'sub-techniques': ['Threat Intel Vendors',
#    'Purchase Technical Data']},
#  'Search Open Technical Databases': {'sub-techniques': ['DNS/Passive DNS',
#    'WHOIS',
#    'Digital Certificates',
#    'CDNs',
#    'Scan Databases']},
#  'Search Open Websites/Domains': {'sub-techniques': ['Social Media',
#    'Search Engines',
#    'Code Repositories']},
#  'Search Victim-Owned Websites': {'sub-techniques': []},
#  'Server Software Component': {'sub-techniques': ['SQL Stored Procedures',
#    'Transport Agent',
#    'Web Shell',
#    'IIS Components',
#    'Terminal Services DLL']},
#  'Serverless Execution': {'sub-techniques': []},
#  'Service Stop': {'sub-techniques': []},
#  'Shared Modules': {'sub-techniques': []},
#  'Software Deployment Tools': {'sub-techniques': []},
#  'Software Discovery': {'sub-techniques': ['Security Software Discovery']},
#  'Stage Capabilities': {'sub-techniques': ['Upload Malware',
#    'Upload Tool',
#    'Install Digital Certificate',
#    'Drive-by Target',
#    'Link Target',
#    'SEO Poisoning']},
#  'Steal Application Access Token': {'sub-techniques': []},
#  'Steal or Forge Authentication Certificates': {'sub-techniques': []},
#  'Steal or Forge Kerberos Tickets': {'sub-techniques': ['Golden Ticket',
#    'Silver Ticket',
#    'Kerberoasting',
#    'AS-REP Roasting']},
#  'Steal Web Session Cookie': {'sub-techniques': []},
#  'Subvert Trust Controls': {'sub-techniques': ['Gatekeeper Bypass',
#    'Code Signing',
#    'SIP and Trust Provider Hijacking',
#    'Install Root Certificate',
#    'Mark-of-the-Web Bypass',
#    'Code Signing Policy Modification']},
#  'Supply Chain Compromise': {'sub-techniques': ['Compromise Software Dependencies and Development Tools',
#    'Compromise Software Supply Chain',
#    'Compromise Hardware Supply Chain']},
#  'System Binary Proxy Execution': {'sub-techniques': ['Compiled HTML File',
#    'Control Panel',
#    'CMSTP',
#    'InstallUtil',
#    'Mshta',
#    'Msiexec',
#    'Odbcconf',
#    'Regsvcs/Regasm',
#    'Regsvr32',
#    'Rundll32',
#    'Verclsid',
#    'Mavinject',
#    'MMC',
#    'Electron Applications']},
#  'System Information Discovery': {'sub-techniques': []},
#  'System Location Discovery': {'sub-techniques': ['System Language Discovery']},
#  'System Network Configuration Discovery': {'sub-techniques': ['Internet Connection Discovery',
#    'Wi-Fi Discovery']},
#  'System Network Connections Discovery': {'sub-techniques': []},
#  'System Owner/User Discovery': {'sub-techniques': []},
#  'System Script Proxy Execution': {'sub-techniques': ['PubPrn',
#    'SyncAppvPublishingServer']},
#  'System Service Discovery': {'sub-techniques': []},
#  'System Services': {'sub-techniques': ['Launchctl', 'Service Execution']},
#  'System Shutdown/Reboot': {'sub-techniques': []},
#  'System Time Discovery': {'sub-techniques': []},
#  'Taint Shared Content': {'sub-techniques': []},
#  'Template Injection': {'sub-techniques': []},
#  'Traffic Signaling': {'sub-techniques': ['Port Knocking', 'Socket Filters']},
#  'Transfer Data to Cloud Account': {'sub-techniques': []},
#  'Trusted Developer Utilities Proxy Execution': {'sub-techniques': ['MSBuild']},
#  'Trusted Relationship': {'sub-techniques': []},
#  'Unsecured Credentials': {'sub-techniques': ['Credentials In Files',
#    'Credentials in Registry',
#    'Bash History',
#    'Private Keys',
#    'Cloud Instance Metadata API',
#    'Group Policy Preferences',
#    'Container API',
#    'Chat Messages']},
#  'Unused/Unsupported Cloud Regions': {'sub-techniques': []},
#  'Use Alternate Authentication Material': {'sub-techniques': ['Application Access Token',
#    'Pass the Hash',
#    'Pass the Ticket',
#    'Web Session Cookie']},
#  'User Execution': {'sub-techniques': ['Malicious Link',
#    'Malicious File',
#    'Malicious Image']},
#  'Valid Accounts': {'sub-techniques': ['Default Accounts',
#    'Domain Accounts',
#    'Local Accounts',
#    'Cloud Accounts']},
#  'Video Capture': {'sub-techniques': []},
#  'Virtualization/Sandbox Evasion': {'sub-techniques': ['System Checks',
#    'User Activity Based Checks',
#    'Time Based Evasion']},
#  'Weaken Encryption': {'sub-techniques': ['Reduce Key Space',
#    'Disable Crypto Hardware']},
#  'Web Service': {'sub-techniques': ['Dead Drop Resolver',
#    'Bidirectional Communication',
#    'One-Way Communication']},
#  'Windows Management Instrumentation': {'sub-techniques': []},
#  'XSL Script Processing': {'sub-techniques': []}}

# %%
techniques_dict['Abuse Elevation Control Mechanism']
# Out:
# {'sub-techniques': ['Setuid and Setgid',
#   'Bypass User Account Control',
#   'Sudo and Sudo Caching',
#   'Elevated Execution with Prompt',
#   'Temporary Elevated Cloud Access',
#   'TCC Manipulation']}

# %%
tabs = pd.read_html('https://attack.mitre.org/matrices/enterprise/#')

# %%
df = tabs[0]
df.head()
# Out:
#                                       Reconnaissance  \
#                                        10 techniques
# 0  Active Scanning (3)  = Scanning IP Blocks  Vul...
# 1                                Active Scanning (3)
# 2                                Active Scanning (3)
# 3                 Gather Victim Host Information (4)
# 4                 Gather Victim Host Information (4)
#
#                                 Resource Development  \
#                                         8 techniques
# 0  Acquire Access  Acquire Infrastructure (8)  = ...
# 1                                                  =
# 2                                                NaN
# 3                                                  =
# 4                                                NaN
#
#                                       Initial Access  \
#                                        10 techniques
# 0  Content Injection  Drive-by Compromise  Exploi...
# 1  Scanning IP Blocks  Vulnerability Scanning  Wo...
# 2                                                NaN
# 3  Hardware  Software  Firmware  Client Configura...
# 4                                                NaN
#
#                                            Execution  \
#                                        14 techniques
# 0  Cloud Administration Command  Command and Scri...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Persistence  \
#                                        20 techniques
# 0  Account Manipulation (6)  = Additional Cloud C...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                 Privilege Escalation  \
#                                        14 techniques
# 0  Abuse Elevation Control Mechanism (6)  = Setui...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                      Defense Evasion  \
#                                        43 techniques
# 0  Abuse Elevation Control Mechanism (6)  = Setui...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                    Credential Access  \
#                                        17 techniques
# 0  Adversary-in-the-Middle (3)  = LLMNR/NBT-NS Po...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                            Discovery  \
#                                        32 techniques
# 0  Account Discovery (4)  = Local Account  Domain...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                     Lateral Movement  \
#                                         9 techniques
# 0  Exploitation of Remote Services  Internal Spea...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Collection  \
#                                        17 techniques
# 0  Adversary-in-the-Middle (3)  = LLMNR/NBT-NS Po...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                  Command and Control  \
#                                        18 techniques
# 0  Application Layer Protocol (4)  = Web Protocol...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Exfiltration  \
#                                         9 techniques
# 0  Automated Exfiltration (1)  = Traffic Duplicat...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                               Impact
#                                        14 techniques
# 0  Account Access Removal  Data Destruction  Data...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
df.iloc[0][0]
# Out:
# 'Active Scanning\xa0(3)  = Scanning IP Blocks  Vulnerability Scanning  Wordlist Scanning  Gather Victim Host Information\xa0(4)  = Hardware  Software  Firmware  Client Configurations  Gather Victim Identity Information\xa0(3)  = Credentials  Email Addresses  Employee Names  Gather Victim Network Information\xa0(6)  = Domain Properties  DNS  Network Trust Dependencies  Network Topology  IP Addresses  Network Security Appliances  Gather Victim Org Information\xa0(4)  = Determine Physical Locations  Business Relationships  Identify Business Tempo  Identify Roles  Phishing for Information\xa0(4)  = Spearphishing Service  Spearphishing Attachment  Spearphishing Link  Spearphishing Voice  Search Closed Sources\xa0(2)  = Threat Intel Vendors  Purchase Technical Data  Search Open Technical Databases\xa0(5)  = DNS/Passive DNS  WHOIS  Digital Certificates  CDNs  Scan Databases  Search Open Websites/Domains\xa0(3)  = Social Media  Search Engines  Code Repositories  Search Victim-Owned Websites'

# %%
def clean_and_split_text(text):

    cleaned_text = text.replace('= ', '')

    separated_text = re.split(r'\s\s+', cleaned_text)

    cleaned_groups = [re.sub(r'\s*\(\d+\)\s*', '', part).strip() for part in separated_text]

    return cleaned_groups

# %%
multi_index_data = df.columns
multi_index_data
# Out:
# MultiIndex([(      'Reconnaissance', '10 techniques'),
#             ('Resource Development',  '8 techniques'),
#             (      'Initial Access', '10 techniques'),
#             (           'Execution', '14 techniques'),
#             (         'Persistence', '20 techniques'),
#             ('Privilege Escalation', '14 techniques'),
#             (     'Defense Evasion', '43 techniques'),
#             (   'Credential Access', '17 techniques'),
#             (           'Discovery', '32 techniques'),
#             (    'Lateral Movement',  '9 techniques'),
#             (          'Collection', '17 techniques'),
#             ( 'Command and Control', '18 techniques'),
#             (        'Exfiltration',  '9 techniques'),
#             (              'Impact', '14 techniques')],
#            )

# %%
tactics_dict = {}

for key, value in multi_index_data:

    tactic_name = key
    num_techniques = int(value.split()[0])

    tactics_dict[tactic_name] = num_techniques

print(tactics_dict)
# Out:
# {'Reconnaissance': 10, 'Resource Development': 8, 'Initial Access': 10, 'Execution': 14, 'Persistence': 20, 'Privilege Escalation': 14, 'Defense Evasion': 43, 'Credential Access': 17, 'Discovery': 32, 'Lateral Movement': 9, 'Collection': 17, 'Command and Control': 18, 'Exfiltration': 9, 'Impact': 14}

# %%
t = []
for key in tactics_dict.keys():
  t.append(key)
print(t)
# Out:
# ['Reconnaissance', 'Resource Development', 'Initial Access', 'Execution', 'Persistence', 'Privilege Escalation', 'Defense Evasion', 'Credential Access', 'Discovery', 'Lateral Movement', 'Collection', 'Command and Control', 'Exfiltration', 'Impact']

# %%
result = {}

for i in range(len(t)):
    chunk = df.iloc[0][i]
    cleaned_text = clean_and_split_text(chunk)

    result[t[i]] = {'techniques': []}

    for technique in techniques_dict.keys():
        if technique in cleaned_text:
            result[t[i]]['techniques'].append(technique)


result
# Out:
# {'Reconnaissance': {'techniques': ['Active Scanning',
#    'Gather Victim Host Information',
#    'Gather Victim Identity Information',
#    'Gather Victim Network Information',
#    'Gather Victim Org Information',
#    'Phishing for Information',
#    'Search Closed Sources',
#    'Search Open Technical Databases',
#    'Search Open Websites/Domains',
#    'Search Victim-Owned Websites']},
#  'Resource Development': {'techniques': ['Acquire Access',
#    'Acquire Infrastructure',
#    'Compromise Accounts',
#    'Compromise Infrastructure',
#    'Develop Capabilities',
#    'Establish Accounts',
#    'Obtain Capabilities',
#    'Stage Capabilities']},
#  'Initial Access': {'techniques': ['Content Injection',
#    'Drive-by Compromise',
#    'Exploit Public-Facing Application',
#    'External Remote Services',
#    'Hardware Additions',
#    'Phishing',
#    'Replication Through Removable Media',
#    'Supply Chain Compromise',
#    'Trusted Relationship',
#    'Valid Accounts']},
#  'Execution': {'techniques': ['Cloud Administration Command',
#    'Command and Scripting Interpreter',
#    'Container Administration Command',
#    'Deploy Container',
#    'Exploitation for Client Execution',
#    'Inter-Process Communication',
#    'Native API',
#    'Scheduled Task/Job',
#    'Serverless Execution',
#    'Shared Modules',
#    'Software Deployment Tools',
#    'System Services',
#    'User Execution',
#    'Windows Management Instrumentation']},
#  'Persistence': {'techniques': ['Account Manipulation',
#    'BITS Jobs',
#    'Boot or Logon Autostart Execution',
#    'Boot or Logon Initialization Scripts',
#    'Browser Extensions',
#    'Compromise Host Software Binary',
#    'Create Account',
#    'Create or Modify System Process',
#    'Event Triggered Execution',
#    'External Remote Services',
#    'Hijack Execution Flow',
#    'Implant Internal Image',
#    'Modify Authentication Process',
#    'Office Application Startup',
#    'Power Settings',
#    'Pre-OS Boot',
#    'Scheduled Task/Job',
#    'Server Software Component',
#    'Traffic Signaling',
#    'Valid Accounts']},
#  'Privilege Escalation': {'techniques': ['Abuse Elevation Control Mechanism',
#    'Access Token Manipulation',
#    'Account Manipulation',
#    'Boot or Logon Autostart Execution',
#    'Boot or Logon Initialization Scripts',
#    'Create or Modify System Process',
#    'Domain or Tenant Policy Modification',
#    'Escape to Host',
#    'Event Triggered Execution',
#    'Exploitation for Privilege Escalation',
#    'Hijack Execution Flow',
#    'Process Injection',
#    'Scheduled Task/Job',
#    'Valid Accounts']},
#  'Defense Evasion': {'techniques': ['Abuse Elevation Control Mechanism',
#    'Access Token Manipulation',
#    'BITS Jobs',
#    'Build Image on Host',
#    'Debugger Evasion',
#    'Deobfuscate/Decode Files or Information',
#    'Deploy Container',
#    'Direct Volume Access',
#    'Domain or Tenant Policy Modification',
#    'Execution Guardrails',
#    'Exploitation for Defense Evasion',
#    'File and Directory Permissions Modification',
#    'Hide Artifacts',
#    'Hijack Execution Flow',
#    'Impair Defenses',
#    'Impersonation',
#    'Indicator Removal',
#    'Indirect Command Execution',
#    'Masquerading',
#    'Modify Authentication Process',
#    'Modify Cloud Compute Infrastructure',
#    'Modify Registry',
#    'Modify System Image',
#    'Network Boundary Bridging',
#    'Obfuscated Files or Information',
#    'Plist File Modification',
#    'Pre-OS Boot',
#    'Process Injection',
#    'Reflective Code Loading',
#    'Rogue Domain Controller',
#    'Rootkit',
#    'Subvert Trust Controls',
#    'System Binary Proxy Execution',
#    'System Script Proxy Execution',
#    'Template Injection',
#    'Traffic Signaling',
#    'Trusted Developer Utilities Proxy Execution',
#    'Unused/Unsupported Cloud Regions',
#    'Use Alternate Authentication Material',
#    'Valid Accounts',
#    'Virtualization/Sandbox Evasion',
#    'Weaken Encryption',
#    'XSL Script Processing']},
#  'Credential Access': {'techniques': ['Adversary-in-the-Middle',
#    'Brute Force',
#    'Credentials from Password Stores',
#    'Exploitation for Credential Access',
#    'Forced Authentication',
#    'Forge Web Credentials',
#    'Input Capture',
#    'Modify Authentication Process',
#    'Multi-Factor Authentication Interception',
#    'Multi-Factor Authentication Request Generation',
#    'Network Sniffing',
#    'OS Credential Dumping',
#    'Steal Application Access Token',
#    'Steal or Forge Authentication Certificates',
#    'Steal or Forge Kerberos Tickets',
#    'Steal Web Session Cookie',
#    'Unsecured Credentials']},
#  'Discovery': {'techniques': ['Account Discovery',
#    'Application Window Discovery',
#    'Browser Information Discovery',
#    'Cloud Infrastructure Discovery',
#    'Cloud Service Dashboard',
#    'Cloud Service Discovery',
#    'Cloud Storage Object Discovery',
#    'Container and Resource Discovery',
#    'Debugger Evasion',
#    'Device Driver Discovery',
#    'Domain Trust Discovery',
#    'File and Directory Discovery',
#    'Group Policy Discovery',
#    'Log Enumeration',
#    'Network Service Discovery',
#    'Network Share Discovery',
#    'Network Sniffing',
#    'Password Policy Discovery',
#    'Peripheral Device Discovery',
#    'Permission Groups Discovery',
#    'Process Discovery',
#    'Query Registry',
#    'Remote System Discovery',
#    'Software Discovery',
#    'System Information Discovery',
#    'System Location Discovery',
#    'System Network Configuration Discovery',
#    'System Network Connections Discovery',
#    'System Owner/User Discovery',
#    'System Service Discovery',
#    'System Time Discovery',
#    'Virtualization/Sandbox Evasion']},
#  'Lateral Movement': {'techniques': ['Exploitation of Remote Services',
#    'Internal Spearphishing',
#    'Lateral Tool Transfer',
#    'Remote Service Session Hijacking',
#    'Remote Services',
#    'Replication Through Removable Media',
#    'Software Deployment Tools',
#    'Taint Shared Content',
#    'Use Alternate Authentication Material']},
#  'Collection': {'techniques': ['Adversary-in-the-Middle',
#    'Archive Collected Data',
#    'Audio Capture',
#    'Automated Collection',
#    'Browser Session Hijacking',
#    'Clipboard Data',
#    'Data from Cloud Storage',
#    'Data from Configuration Repository',
#    'Data from Information Repositories',
#    'Data from Local System',
#    'Data from Network Shared Drive',
#    'Data from Removable Media',
#    'Data Staged',
#    'Email Collection',
#    'Input Capture',
#    'Screen Capture',
#    'Video Capture']},
#  'Command and Control': {'techniques': ['Application Layer Protocol',
#    'Communication Through Removable Media',
#    'Content Injection',
#    'Data Encoding',
#    'Data Obfuscation',
#    'Dynamic Resolution',
#    'Encrypted Channel',
#    'Fallback Channels',
#    'Hide Infrastructure',
#    'Ingress Tool Transfer',
#    'Multi-Stage Channels',
#    'Non-Application Layer Protocol',
#    'Non-Standard Port',
#    'Protocol Tunneling',
#    'Proxy',
#    'Remote Access Software',
#    'Traffic Signaling',
#    'Web Service']},
#  'Exfiltration': {'techniques': ['Automated Exfiltration',
#    'Data Transfer Size Limits',
#    'Exfiltration Over Alternative Protocol',
#    'Exfiltration Over C2 Channel',
#    'Exfiltration Over Other Network Medium',
#    'Exfiltration Over Physical Medium',
#    'Exfiltration Over Web Service',
#    'Scheduled Transfer',
#    'Transfer Data to Cloud Account']},
#  'Impact': {'techniques': ['Account Access Removal',
#    'Data Destruction',
#    'Data Encrypted for Impact',
#    'Data Manipulation',
#    'Defacement',
#    'Disk Wipe',
#    'Endpoint Denial of Service',
#    'Financial Theft',
#    'Firmware Corruption',
#    'Inhibit System Recovery',
#    'Network Denial of Service',
#    'Resource Hijacking',
#    'Service Stop',
#    'System Shutdown/Reboot']}}

# %%
final_json = {}

for tactic, info in result.items():
    techniques = info['techniques']
    final_json[tactic] = {}
    for technique in techniques:
        final_json[tactic][technique] = {
            'sub-techniques': techniques_dict.get(technique, {}).get('sub-techniques', [])
        }

final_json_str = json.dumps(final_json, indent=4)

print(final_json_str)
# Out:
# {
#     "Reconnaissance": {
#         "Active Scanning": {
#             "sub-techniques": [
#                 "Scanning IP Blocks",
#                 "Vulnerability Scanning",
#                 "Wordlist Scanning"
#             ]
#         },
#         "Gather Victim Host Information": {
#             "sub-techniques": [
#                 "Hardware",
#                 "Software",
#                 "Firmware",
#                 "Client Configurations"
#             ]
#         },
#         "Gather Victim Identity Information": {
#             "sub-techniques": [
#                 "Credentials",
#                 "Email Addresses",
#                 "Employee Names"
#             ]
#         },
#         "Gather Victim Network Information": {
#             "sub-techniques": [
#                 "Domain Properties",
#                 "DNS",
#                 "Network Trust Dependencies",
#                 "Network Topology",
#                 "IP Addresses",
#                 "Network Security Appliances"
#             ]
#         },
#         "Gather Victim Org Information": {
#             "sub-techniques": [
#                 "Determine Physical Locations",
#                 "Business Relationships",
#                 "Identify Business Tempo",
#                 "Identify Roles"
#             ]
#         },
#         "Phishing for Information": {
#             "sub-techniques": [
#                 "Spearphishing Service",
#                 "Spearphishing Attachment",
#                 "Spearphishing Link",
#                 "Spearphishing Voice"
#             ]
#         },
#         "Search Closed Sources": {
#             "sub-techniques": [
#                 "Threat Intel Vendors",
#                 "Purchase Technical Data"
#             ]
#         },
#         "Search Open Technical Databases": {
#             "sub-techniques": [
#                 "DNS/Passive DNS",
#                 "WHOIS",
#                 "Digital Certificates",
#                 "CDNs",
#                 "Scan Databases"
#             ]
#         },
#         "Search Open Websites/Domains": {
#             "sub-techniques": [
#                 "Social Media",
#                 "Search Engines",
#                 "Code Repositories"
#             ]
#         },
#         "Search Victim-Owned Websites": {
#             "sub-techniques": []
#         }
#     },
#     "Resource Development": {
#         "Acquire Access": {
#             "sub-techniques": []
#         },
#         "Acquire Infrastructure": {
#             "sub-techniques": [
#                 "Domains",
#                 "DNS Server",
#                 "Virtual Private Server",
#                 "Server",
#                 "Botnet",
#                 "Web Services",
#                 "Serverless",
#                 "Malvertising"
#             ]
#         },
#         "Compromise Accounts": {
#             "sub-techniques": [
#                 "Social Media Accounts",
#                 "Email Accounts",
#                 "Cloud Accounts"
#             ]
#         },
#         "Compromise Infrastructure": {
#             "sub-techniques": [
#                 "Domains",
#                 "DNS Server",
#                 "Virtual Private Server",
#                 "Server",
#                 "Botnet",
#                 "Web Services",
#                 "Serverless",
#                 "Network Devices"
#             ]
#         },
#         "Develop Capabilities": {
#             "sub-techniques": [
#                 "Malware",
#                 "Code Signing Certificates",
#                 "Digital Certificates",
#                 "Exploits"
#             ]
#         },
#         "Establish Accounts": {
#             "sub-techniques": [
#                 "Social Media Accounts",
#                 "Email Accounts",
#                 "Cloud Accounts"
#             ]
#         },
#         "Obtain Capabilities": {
#             "sub-techniques": [
#                 "Malware",
#                 "Tool",
#                 "Code Signing Certificates",
#                 "Digital Certificates",
#                 "Exploits",
#                 "Vulnerabilities",
#                 "Artificial Intelligence"
#             ]
#         },
#         "Stage Capabilities": {
#             "sub-techniques": [
#                 "Upload Malware",
#                 "Upload Tool",
#                 "Install Digital Certificate",
#                 "Drive-by Target",
#                 "Link Target",
#                 "SEO Poisoning"
#             ]
#         }
#     },
#     "Initial Access": {
#         "Content Injection": {
#             "sub-techniques": []
#         },
#         "Drive-by Compromise": {
#             "sub-techniques": []
#         },
#         "Exploit Public-Facing Application": {
#             "sub-techniques": []
#         },
#         "External Remote Services": {
#             "sub-techniques": []
#         },
#         "Hardware Additions": {
#             "sub-techniques": []
#         },
#         "Phishing": {
#             "sub-techniques": [
#                 "Spearphishing Attachment",
#                 "Spearphishing Link",
#                 "Spearphishing via Service",
#                 "Spearphishing Voice"
#             ]
#         },
#         "Replication Through Removable Media": {
#             "sub-techniques": []
#         },
#         "Supply Chain Compromise": {
#             "sub-techniques": [
#                 "Compromise Software Dependencies and Development Tools",
#                 "Compromise Software Supply Chain",
#                 "Compromise Hardware Supply Chain"
#             ]
#         },
#         "Trusted Relationship": {
#             "sub-techniques": []
#         },
#         "Valid Accounts": {
#             "sub-techniques": [
#                 "Default Accounts",
#                 "Domain Accounts",
#                 "Local Accounts",
#                 "Cloud Accounts"
#             ]
#         }
#     },
#     "Execution": {
#         "Cloud Administration Command": {
#             "sub-techniques": []
#         },
#         "Command and Scripting Interpreter": {
#             "sub-techniques": [
#                 "PowerShell",
#                 "AppleScript",
#                 "Windows Command Shell",
#                 "Unix Shell",
#                 "Visual Basic",
#                 "Python",
#                 "JavaScript",
#                 "Network Device CLI",
#                 "Cloud API",
#                 "AutoHotKey & AutoIT"
#             ]
#         },
#         "Container Administration Command": {
#             "sub-techniques": []
#         },
#         "Deploy Container": {
#             "sub-techniques": []
#         },
#         "Exploitation for Client Execution": {
#             "sub-techniques": []
#         },
#         "Inter-Process Communication": {
#             "sub-techniques": [
#                 "Component Object Model",
#                 "Dynamic Data Exchange",
#                 "XPC Services"
#             ]
#         },
#         "Native API": {
#             "sub-techniques": []
#         },
#         "Scheduled Task/Job": {
#             "sub-techniques": [
#                 "At",
#                 "Cron",
#                 "Scheduled Task",
#                 "Systemd Timers",
#                 "Container Orchestration Job"
#             ]
#         },
#         "Serverless Execution": {
#             "sub-techniques": []
#         },
#         "Shared Modules": {
#             "sub-techniques": []
#         },
#         "Software Deployment Tools": {
#             "sub-techniques": []
#         },
#         "System Services": {
#             "sub-techniques": [
#                 "Launchctl",
#                 "Service Execution"
#             ]
#         },
#         "User Execution": {
#             "sub-techniques": [
#                 "Malicious Link",
#                 "Malicious File",
#                 "Malicious Image"
#             ]
#         },
#         "Windows Management Instrumentation": {
#             "sub-techniques": []
#         }
#     },
#     "Persistence": {
#         "Account Manipulation": {
#             "sub-techniques": [
#                 "Additional Cloud Credentials",
#                 "Additional Email Delegate Permissions",
#                 "Additional Cloud Roles",
#                 "SSH Authorized Keys",
#                 "Device Registration",
#                 "Additional Container Cluster Roles"
#             ]
#         },
#         "BITS Jobs": {
#             "sub-techniques": []
#         },
#         "Boot or Logon Autostart Execution": {
#             "sub-techniques": [
#                 "Registry Run Keys / Startup Folder",
#                 "Authentication Package",
#                 "Time Providers",
#                 "Winlogon Helper DLL",
#                 "Security Support Provider",
#                 "Kernel Modules and Extensions",
#                 "Re-opened Applications",
#                 "LSASS Driver",
#                 "Shortcut Modification",
#                 "Port Monitors",
#                 "Print Processors",
#                 "XDG Autostart Entries",
#                 "Active Setup",
#                 "Login Items"
#             ]
#         },
#         "Boot or Logon Initialization Scripts": {
#             "sub-techniques": [
#                 "Logon Script (Windows)",
#                 "Login Hook",
#                 "Network Logon Script",
#                 "RC Scripts",
#                 "Startup Items"
#             ]
#         },
#         "Browser Extensions": {
#             "sub-techniques": []
#         },
#         "Compromise Host Software Binary": {
#             "sub-techniques": []
#         },
#         "Create Account": {
#             "sub-techniques": [
#                 "Local Account",
#                 "Domain Account",
#                 "Cloud Account"
#             ]
#         },
#         "Create or Modify System Process": {
#             "sub-techniques": [
#                 "Launch Agent",
#                 "Systemd Service",
#                 "Windows Service",
#                 "Launch Daemon",
#                 "Container Service"
#             ]
#         },
#         "Event Triggered Execution": {
#             "sub-techniques": [
#                 "Change Default File Association",
#                 "Screensaver",
#                 "Windows Management Instrumentation Event Subscription",
#                 "Unix Shell Configuration Modification",
#                 "Trap",
#                 "LC_LOAD_DYLIB Addition",
#                 "Netsh Helper DLL",
#                 "Accessibility Features",
#                 "AppCert DLLs",
#                 "AppInit DLLs",
#                 "Application Shimming",
#                 "Image File Execution Options Injection",
#                 "PowerShell Profile",
#                 "Emond",
#                 "Component Object Model Hijacking",
#                 "Installer Packages"
#             ]
#         },
#         "External Remote Services": {
#             "sub-techniques": []
#         },
#         "Hijack Execution Flow": {
#             "sub-techniques": [
#                 "DLL Search Order Hijacking",
#                 "DLL Side-Loading",
#                 "Dylib Hijacking",
#                 "Executable Installer File Permissions Weakness",
#                 "Dynamic Linker Hijacking",
#                 "Path Interception by PATH Environment Variable",
#                 "Path Interception by Search Order Hijacking",
#                 "Path Interception by Unquoted Path",
#                 "Services File Permissions Weakness",
#                 "Services Registry Permissions Weakness",
#                 "COR_PROFILER",
#                 "KernelCallbackTable",
#                 "AppDomainManager"
#             ]
#         },
#         "Implant Internal Image": {
#             "sub-techniques": []
#         },
#         "Modify Authentication Process": {
#             "sub-techniques": [
#                 "Domain Controller Authentication",
#                 "Password Filter DLL",
#                 "Pluggable Authentication Modules",
#                 "Network Device Authentication",
#                 "Reversible Encryption",
#                 "Multi-Factor Authentication",
#                 "Hybrid Identity",
#                 "Network Provider DLL",
#                 "Conditional Access Policies"
#             ]
#         },
#         "Office Application Startup": {
#             "sub-techniques": [
#                 "Office Template Macros",
#                 "Office Test",
#                 "Outlook Forms",
#                 "Outlook Home Page",
#                 "Outlook Rules",
#                 "Add-ins"
#             ]
#         },
#         "Power Settings": {
#             "sub-techniques": []
#         },
#         "Pre-OS Boot": {
#             "sub-techniques": [
#                 "System Firmware",
#                 "Component Firmware",
#                 "Bootkit",
#                 "ROMMONkit",
#                 "TFTP Boot"
#             ]
#         },
#         "Scheduled Task/Job": {
#             "sub-techniques": [
#                 "At",
#                 "Cron",
#                 "Scheduled Task",
#                 "Systemd Timers",
#                 "Container Orchestration Job"
#             ]
#         },
#         "Server Software Component": {
#             "sub-techniques": [
#                 "SQL Stored Procedures",
#                 "Transport Agent",
#                 "Web Shell",
#                 "IIS Components",
#                 "Terminal Services DLL"
#             ]
#         },
#         "Traffic Signaling": {
#             "sub-techniques": [
#                 "Port Knocking",
#                 "Socket Filters"
#             ]
#         },
#         "Valid Accounts": {
#             "sub-techniques": [
#                 "Default Accounts",
#                 "Domain Accounts",
#                 "Local Accounts",
#                 "Cloud Accounts"
#             ]
#         }
#     },
#     "Privilege Escalation": {
#         "Abuse Elevation Control Mechanism": {
#             "sub-techniques": [
#                 "Setuid and Setgid",
#                 "Bypass User Account Control",
#                 "Sudo and Sudo Caching",
#                 "Elevated Execution with Prompt",
#                 "Temporary Elevated Cloud Access",
#                 "TCC Manipulation"
#             ]
#         },
#         "Access Token Manipulation": {
#             "sub-techniques": [
#                 "Token Impersonation/Theft",
#                 "Create Process with Token",
#                 "Make and Impersonate Token",
#                 "Parent PID Spoofing",
#                 "SID-History Injection"
#             ]
#         },
#         "Account Manipulation": {
#             "sub-techniques": [
#                 "Additional Cloud Credentials",
#                 "Additional Email Delegate Permissions",
#                 "Additional Cloud Roles",
#                 "SSH Authorized Keys",
#                 "Device Registration",
#                 "Additional Container Cluster Roles"
#             ]
#         },
#         "Boot or Logon Autostart Execution": {
#             "sub-techniques": [
#                 "Registry Run Keys / Startup Folder",
#                 "Authentication Package",
#                 "Time Providers",
#                 "Winlogon Helper DLL",
#                 "Security Support Provider",
#                 "Kernel Modules and Extensions",
#                 "Re-opened Applications",
#                 "LSASS Driver",
#                 "Shortcut Modification",
#                 "Port Monitors",
#                 "Print Processors",
#                 "XDG Autostart Entries",
#                 "Active Setup",
#                 "Login Items"
#             ]
#         },
#         "Boot or Logon Initialization Scripts": {
#             "sub-techniques": [
#                 "Logon Script (Windows)",
#                 "Login Hook",
#                 "Network Logon Script",
#                 "RC Scripts",
#                 "Startup Items"
#             ]
#         },
#         "Create or Modify System Process": {
#             "sub-techniques": [
#                 "Launch Agent",
#                 "Systemd Service",
#                 "Windows Service",
#                 "Launch Daemon",
#                 "Container Service"
#             ]
#         },
#         "Domain or Tenant Policy Modification": {
#             "sub-techniques": [
#                 "Group Policy Modification",
#                 "Trust Modification"
#             ]
#         },
#         "Escape to Host": {
#             "sub-techniques": []
#         },
#         "Event Triggered Execution": {
#             "sub-techniques": [
#                 "Change Default File Association",
#                 "Screensaver",
#                 "Windows Management Instrumentation Event Subscription",
#                 "Unix Shell Configuration Modification",
#                 "Trap",
#                 "LC_LOAD_DYLIB Addition",
#                 "Netsh Helper DLL",
#                 "Accessibility Features",
#                 "AppCert DLLs",
#                 "AppInit DLLs",
#                 "Application Shimming",
#                 "Image File Execution Options Injection",
#                 "PowerShell Profile",
#                 "Emond",
#                 "Component Object Model Hijacking",
#                 "Installer Packages"
#             ]
#         },
#         "Exploitation for Privilege Escalation": {
#             "sub-techniques": []
#         },
#         "Hijack Execution Flow": {
#             "sub-techniques": [
#                 "DLL Search Order Hijacking",
#                 "DLL Side-Loading",
#                 "Dylib Hijacking",
#                 "Executable Installer File Permissions Weakness",
#                 "Dynamic Linker Hijacking",
#                 "Path Interception by PATH Environment Variable",
#                 "Path Interception by Search Order Hijacking",
#                 "Path Interception by Unquoted Path",
#                 "Services File Permissions Weakness",
#                 "Services Registry Permissions Weakness",
#                 "COR_PROFILER",
#                 "KernelCallbackTable",
#                 "AppDomainManager"
#             ]
#         },
#         "Process Injection": {
#             "sub-techniques": [
#                 "Dynamic-link Library Injection",
#                 "Portable Executable Injection",
#                 "Thread Execution Hijacking",
#                 "Asynchronous Procedure Call",
#                 "Thread Local Storage",
#                 "Ptrace System Calls",
#                 "Proc Memory",
#                 "Extra Window Memory Injection",
#                 "Process Hollowing",
#                 "Process Doppelg\u00e4nging",
#                 "VDSO Hijacking",
#                 "ListPlanting"
#             ]
#         },
#         "Scheduled Task/Job": {
#             "sub-techniques": [
#                 "At",
#                 "Cron",
#                 "Scheduled Task",
#                 "Systemd Timers",
#                 "Container Orchestration Job"
#             ]
#         },
#         "Valid Accounts": {
#             "sub-techniques": [
#                 "Default Accounts",
#                 "Domain Accounts",
#                 "Local Accounts",
#                 "Cloud Accounts"
#             ]
#         }
#     },
#     "Defense Evasion": {
#         "Abuse Elevation Control Mechanism": {
#             "sub-techniques": [
#                 "Setuid and Setgid",
#                 "Bypass User Account Control",
#                 "Sudo and Sudo Caching",
#                 "Elevated Execution with Prompt",
#                 "Temporary Elevated Cloud Access",
#                 "TCC Manipulation"
#             ]
#         },
#         "Access Token Manipulation": {
#             "sub-techniques": [
#                 "Token Impersonation/Theft",
#                 "Create Process with Token",
#                 "Make and Impersonate Token",
#                 "Parent PID Spoofing",
#                 "SID-History Injection"
#             ]
#         },
#         "BITS Jobs": {
#             "sub-techniques": []
#         },
#         "Build Image on Host": {
#             "sub-techniques": []
#         },
#         "Debugger Evasion": {
#             "sub-techniques": []
#         },
#         "Deobfuscate/Decode Files or Information": {
#             "sub-techniques": []
#         },
#         "Deploy Container": {
#             "sub-techniques": []
#         },
#         "Direct Volume Access": {
#             "sub-techniques": []
#         },
#         "Domain or Tenant Policy Modification": {
#             "sub-techniques": [
#                 "Group Policy Modification",
#                 "Trust Modification"
#             ]
#         },
#         "Execution Guardrails": {
#             "sub-techniques": [
#                 "Environmental Keying"
#             ]
#         },
#         "Exploitation for Defense Evasion": {
#             "sub-techniques": []
#         },
#         "File and Directory Permissions Modification": {
#             "sub-techniques": [
#                 "Windows File and Directory Permissions Modification",
#                 "Linux and Mac File and Directory Permissions Modification"
#             ]
#         },
#         "Hide Artifacts": {
#             "sub-techniques": [
#                 "Hidden Files and Directories",
#                 "Hidden Users",
#                 "Hidden Window",
#                 "NTFS File Attributes",
#                 "Hidden File System",
#                 "Run Virtual Instance",
#                 "VBA Stomping",
#                 "Email Hiding Rules",
#                 "Resource Forking",
#                 "Process Argument Spoofing",
#                 "Ignore Process Interrupts",
#                 "File/Path Exclusions"
#             ]
#         },
#         "Hijack Execution Flow": {
#             "sub-techniques": [
#                 "DLL Search Order Hijacking",
#                 "DLL Side-Loading",
#                 "Dylib Hijacking",
#                 "Executable Installer File Permissions Weakness",
#                 "Dynamic Linker Hijacking",
#                 "Path Interception by PATH Environment Variable",
#                 "Path Interception by Search Order Hijacking",
#                 "Path Interception by Unquoted Path",
#                 "Services File Permissions Weakness",
#                 "Services Registry Permissions Weakness",
#                 "COR_PROFILER",
#                 "KernelCallbackTable",
#                 "AppDomainManager"
#             ]
#         },
#         "Impair Defenses": {
#             "sub-techniques": [
#                 "Disable or Modify Tools",
#                 "Disable Windows Event Logging",
#                 "Impair Command History Logging",
#                 "Disable or Modify System Firewall",
#                 "Indicator Blocking",
#                 "Disable or Modify Cloud Firewall",
#                 "Disable or Modify Cloud Logs",
#                 "Safe Mode Boot",
#                 "Downgrade Attack",
#                 "Spoof Security Alerting",
#                 "Disable or Modify Linux Audit System"
#             ]
#         },
#         "Impersonation": {
#             "sub-techniques": []
#         },
#         "Indicator Removal": {
#             "sub-techniques": [
#                 "Clear Windows Event Logs",
#                 "Clear Linux or Mac System Logs",
#                 "Clear Command History",
#                 "File Deletion",
#                 "Network Share Connection Removal",
#                 "Timestomp",
#                 "Clear Network Connection History and Configurations",
#                 "Clear Mailbox Data",
#                 "Clear Persistence"
#             ]
#         },
#         "Indirect Command Execution": {
#             "sub-techniques": []
#         },
#         "Masquerading": {
#             "sub-techniques": [
#                 "Invalid Code Signature",
#                 "Right-to-Left Override",
#                 "Rename System Utilities",
#                 "Masquerade Task or Service",
#                 "Match Legitimate Name or Location",
#                 "Space after Filename",
#                 "Double File Extension",
#                 "Masquerade File Type",
#                 "Break Process Trees"
#             ]
#         },
#         "Modify Authentication Process": {
#             "sub-techniques": [
#                 "Domain Controller Authentication",
#                 "Password Filter DLL",
#                 "Pluggable Authentication Modules",
#                 "Network Device Authentication",
#                 "Reversible Encryption",
#                 "Multi-Factor Authentication",
#                 "Hybrid Identity",
#                 "Network Provider DLL",
#                 "Conditional Access Policies"
#             ]
#         },
#         "Modify Cloud Compute Infrastructure": {
#             "sub-techniques": [
#                 "Create Snapshot",
#                 "Create Cloud Instance",
#                 "Delete Cloud Instance",
#                 "Revert Cloud Instance",
#                 "Modify Cloud Compute Configurations"
#             ]
#         },
#         "Modify Registry": {
#             "sub-techniques": []
#         },
#         "Modify System Image": {
#             "sub-techniques": [
#                 "Patch System Image",
#                 "Downgrade System Image"
#             ]
#         },
#         "Network Boundary Bridging": {
#             "sub-techniques": [
#                 "Network Address Translation Traversal"
#             ]
#         },
#         "Obfuscated Files or Information": {
#             "sub-techniques": [
#                 "Binary Padding",
#                 "Software Packing",
#                 "Steganography",
#                 "Compile After Delivery",
#                 "Indicator Removal from Tools",
#                 "HTML Smuggling",
#                 "Dynamic API Resolution",
#                 "Stripped Payloads",
#                 "Embedded Payloads",
#                 "Command Obfuscation",
#                 "Fileless Storage",
#                 "LNK Icon Smuggling",
#                 "Encrypted/Encoded File"
#             ]
#         },
#         "Plist File Modification": {
#             "sub-techniques": []
#         },
#         "Pre-OS Boot": {
#             "sub-techniques": [
#                 "System Firmware",
#                 "Component Firmware",
#                 "Bootkit",
#                 "ROMMONkit",
#                 "TFTP Boot"
#             ]
#         },
#         "Process Injection": {
#             "sub-techniques": [
#                 "Dynamic-link Library Injection",
#                 "Portable Executable Injection",
#                 "Thread Execution Hijacking",
#                 "Asynchronous Procedure Call",
#                 "Thread Local Storage",
#                 "Ptrace System Calls",
#                 "Proc Memory",
#                 "Extra Window Memory Injection",
#                 "Process Hollowing",
#                 "Process Doppelg\u00e4nging",
#                 "VDSO Hijacking",
#                 "ListPlanting"
#             ]
#         },
#         "Reflective Code Loading": {
#             "sub-techniques": []
#         },
#         "Rogue Domain Controller": {
#             "sub-techniques": []
#         },
#         "Rootkit": {
#             "sub-techniques": []
#         },
#         "Subvert Trust Controls": {
#             "sub-techniques": [
#                 "Gatekeeper Bypass",
#                 "Code Signing",
#                 "SIP and Trust Provider Hijacking",
#                 "Install Root Certificate",
#                 "Mark-of-the-Web Bypass",
#                 "Code Signing Policy Modification"
#             ]
#         },
#         "System Binary Proxy Execution": {
#             "sub-techniques": [
#                 "Compiled HTML File",
#                 "Control Panel",
#                 "CMSTP",
#                 "InstallUtil",
#                 "Mshta",
#                 "Msiexec",
#                 "Odbcconf",
#                 "Regsvcs/Regasm",
#                 "Regsvr32",
#                 "Rundll32",
#                 "Verclsid",
#                 "Mavinject",
#                 "MMC",
#                 "Electron Applications"
#             ]
#         },
#         "System Script Proxy Execution": {
#             "sub-techniques": [
#                 "PubPrn",
#                 "SyncAppvPublishingServer"
#             ]
#         },
#         "Template Injection": {
#             "sub-techniques": []
#         },
#         "Traffic Signaling": {
#             "sub-techniques": [
#                 "Port Knocking",
#                 "Socket Filters"
#             ]
#         },
#         "Trusted Developer Utilities Proxy Execution": {
#             "sub-techniques": [
#                 "MSBuild"
#             ]
#         },
#         "Unused/Unsupported Cloud Regions": {
#             "sub-techniques": []
#         },
#         "Use Alternate Authentication Material": {
#             "sub-techniques": [
#                 "Application Access Token",
#                 "Pass the Hash",
#                 "Pass the Ticket",
#                 "Web Session Cookie"
#             ]
#         },
#         "Valid Accounts": {
#             "sub-techniques": [
#                 "Default Accounts",
#                 "Domain Accounts",
#                 "Local Accounts",
#                 "Cloud Accounts"
#             ]
#         },
#         "Virtualization/Sandbox Evasion": {
#             "sub-techniques": [
#                 "System Checks",
#                 "User Activity Based Checks",
#                 "Time Based Evasion"
#             ]
#         },
#         "Weaken Encryption": {
#             "sub-techniques": [
#                 "Reduce Key Space",
#                 "Disable Crypto Hardware"
#             ]
#         },
#         "XSL Script Processing": {
#             "sub-techniques": []
#         }
#     },
#     "Credential Access": {
#         "Adversary-in-the-Middle": {
#             "sub-techniques": [
#                 "LLMNR/NBT-NS Poisoning and SMB Relay",
#                 "ARP Cache Poisoning",
#                 "DHCP Spoofing"
#             ]
#         },
#         "Brute Force": {
#             "sub-techniques": [
#                 "Password Guessing",
#                 "Password Cracking",
#                 "Password Spraying",
#                 "Credential Stuffing"
#             ]
#         },
#         "Credentials from Password Stores": {
#             "sub-techniques": [
#                 "Keychain",
#                 "Securityd Memory",
#                 "Credentials from Web Browsers",
#                 "Windows Credential Manager",
#                 "Password Managers",
#                 "Cloud Secrets Management Stores"
#             ]
#         },
#         "Exploitation for Credential Access": {
#             "sub-techniques": []
#         },
#         "Forced Authentication": {
#             "sub-techniques": []
#         },
#         "Forge Web Credentials": {
#             "sub-techniques": [
#                 "Web Cookies",
#                 "SAML Tokens"
#             ]
#         },
#         "Input Capture": {
#             "sub-techniques": [
#                 "Keylogging",
#                 "GUI Input Capture",
#                 "Web Portal Capture",
#                 "Credential API Hooking"
#             ]
#         },
#         "Modify Authentication Process": {
#             "sub-techniques": [
#                 "Domain Controller Authentication",
#                 "Password Filter DLL",
#                 "Pluggable Authentication Modules",
#                 "Network Device Authentication",
#                 "Reversible Encryption",
#                 "Multi-Factor Authentication",
#                 "Hybrid Identity",
#                 "Network Provider DLL",
#                 "Conditional Access Policies"
#             ]
#         },
#         "Multi-Factor Authentication Interception": {
#             "sub-techniques": []
#         },
#         "Multi-Factor Authentication Request Generation": {
#             "sub-techniques": []
#         },
#         "Network Sniffing": {
#             "sub-techniques": []
#         },
#         "OS Credential Dumping": {
#             "sub-techniques": [
#                 "LSASS Memory",
#                 "Security Account Manager",
#                 "NTDS",
#                 "LSA Secrets",
#                 "Cached Domain Credentials",
#                 "DCSync",
#                 "Proc Filesystem",
#                 "/etc/passwd and /etc/shadow"
#             ]
#         },
#         "Steal Application Access Token": {
#             "sub-techniques": []
#         },
#         "Steal or Forge Authentication Certificates": {
#             "sub-techniques": []
#         },
#         "Steal or Forge Kerberos Tickets": {
#             "sub-techniques": [
#                 "Golden Ticket",
#                 "Silver Ticket",
#                 "Kerberoasting",
#                 "AS-REP Roasting"
#             ]
#         },
#         "Steal Web Session Cookie": {
#             "sub-techniques": []
#         },
#         "Unsecured Credentials": {
#             "sub-techniques": [
#                 "Credentials In Files",
#                 "Credentials in Registry",
#                 "Bash History",
#                 "Private Keys",
#                 "Cloud Instance Metadata API",
#                 "Group Policy Preferences",
#                 "Container API",
#                 "Chat Messages"
#             ]
#         }
#     },
#     "Discovery": {
#         "Account Discovery": {
#             "sub-techniques": [
#                 "Local Account",
#                 "Domain Account",
#                 "Email Account",
#                 "Cloud Account"
#             ]
#         },
#         "Application Window Discovery": {
#             "sub-techniques": []
#         },
#         "Browser Information Discovery": {
#             "sub-techniques": []
#         },
#         "Cloud Infrastructure Discovery": {
#             "sub-techniques": []
#         },
#         "Cloud Service Dashboard": {
#             "sub-techniques": []
#         },
#         "Cloud Service Discovery": {
#             "sub-techniques": []
#         },
#         "Cloud Storage Object Discovery": {
#             "sub-techniques": []
#         },
#         "Container and Resource Discovery": {
#             "sub-techniques": []
#         },
#         "Debugger Evasion": {
#             "sub-techniques": []
#         },
#         "Device Driver Discovery": {
#             "sub-techniques": []
#         },
#         "Domain Trust Discovery": {
#             "sub-techniques": []
#         },
#         "File and Directory Discovery": {
#             "sub-techniques": []
#         },
#         "Group Policy Discovery": {
#             "sub-techniques": []
#         },
#         "Log Enumeration": {
#             "sub-techniques": []
#         },
#         "Network Service Discovery": {
#             "sub-techniques": []
#         },
#         "Network Share Discovery": {
#             "sub-techniques": []
#         },
#         "Network Sniffing": {
#             "sub-techniques": []
#         },
#         "Password Policy Discovery": {
#             "sub-techniques": []
#         },
#         "Peripheral Device Discovery": {
#             "sub-techniques": []
#         },
#         "Permission Groups Discovery": {
#             "sub-techniques": [
#                 "Local Groups",
#                 "Domain Groups",
#                 "Cloud Groups"
#             ]
#         },
#         "Process Discovery": {
#             "sub-techniques": []
#         },
#         "Query Registry": {
#             "sub-techniques": []
#         },
#         "Remote System Discovery": {
#             "sub-techniques": []
#         },
#         "Software Discovery": {
#             "sub-techniques": [
#                 "Security Software Discovery"
#             ]
#         },
#         "System Information Discovery": {
#             "sub-techniques": []
#         },
#         "System Location Discovery": {
#             "sub-techniques": [
#                 "System Language Discovery"
#             ]
#         },
#         "System Network Configuration Discovery": {
#             "sub-techniques": [
#                 "Internet Connection Discovery",
#                 "Wi-Fi Discovery"
#             ]
#         },
#         "System Network Connections Discovery": {
#             "sub-techniques": []
#         },
#         "System Owner/User Discovery": {
#             "sub-techniques": []
#         },
#         "System Service Discovery": {
#             "sub-techniques": []
#         },
#         "System Time Discovery": {
#             "sub-techniques": []
#         },
#         "Virtualization/Sandbox Evasion": {
#             "sub-techniques": [
#                 "System Checks",
#                 "User Activity Based Checks",
#                 "Time Based Evasion"
#             ]
#         }
#     },
#     "Lateral Movement": {
#         "Exploitation of Remote Services": {
#             "sub-techniques": []
#         },
#         "Internal Spearphishing": {
#             "sub-techniques": []
#         },
#         "Lateral Tool Transfer": {
#             "sub-techniques": []
#         },
#         "Remote Service Session Hijacking": {
#             "sub-techniques": [
#                 "SSH Hijacking",
#                 "RDP Hijacking"
#             ]
#         },
#         "Remote Services": {
#             "sub-techniques": [
#                 "Remote Desktop Protocol",
#                 "SMB/Windows Admin Shares",
#                 "Distributed Component Object Model",
#                 "SSH",
#                 "VNC",
#                 "Windows Remote Management",
#                 "Cloud Services",
#                 "Direct Cloud VM Connections"
#             ]
#         },
#         "Replication Through Removable Media": {
#             "sub-techniques": []
#         },
#         "Software Deployment Tools": {
#             "sub-techniques": []
#         },
#         "Taint Shared Content": {
#             "sub-techniques": []
#         },
#         "Use Alternate Authentication Material": {
#             "sub-techniques": [
#                 "Application Access Token",
#                 "Pass the Hash",
#                 "Pass the Ticket",
#                 "Web Session Cookie"
#             ]
#         }
#     },
#     "Collection": {
#         "Adversary-in-the-Middle": {
#             "sub-techniques": [
#                 "LLMNR/NBT-NS Poisoning and SMB Relay",
#                 "ARP Cache Poisoning",
#                 "DHCP Spoofing"
#             ]
#         },
#         "Archive Collected Data": {
#             "sub-techniques": [
#                 "Archive via Utility",
#                 "Archive via Library",
#                 "Archive via Custom Method"
#             ]
#         },
#         "Audio Capture": {
#             "sub-techniques": []
#         },
#         "Automated Collection": {
#             "sub-techniques": []
#         },
#         "Browser Session Hijacking": {
#             "sub-techniques": []
#         },
#         "Clipboard Data": {
#             "sub-techniques": []
#         },
#         "Data from Cloud Storage": {
#             "sub-techniques": []
#         },
#         "Data from Configuration Repository": {
#             "sub-techniques": [
#                 "SNMP (MIB Dump)",
#                 "Network Device Configuration Dump"
#             ]
#         },
#         "Data from Information Repositories": {
#             "sub-techniques": [
#                 "Confluence",
#                 "Sharepoint",
#                 "Code Repositories"
#             ]
#         },
#         "Data from Local System": {
#             "sub-techniques": []
#         },
#         "Data from Network Shared Drive": {
#             "sub-techniques": []
#         },
#         "Data from Removable Media": {
#             "sub-techniques": []
#         },
#         "Data Staged": {
#             "sub-techniques": [
#                 "Local Data Staging",
#                 "Remote Data Staging"
#             ]
#         },
#         "Email Collection": {
#             "sub-techniques": [
#                 "Local Email Collection",
#                 "Remote Email Collection",
#                 "Email Forwarding Rule"
#             ]
#         },
#         "Input Capture": {
#             "sub-techniques": [
#                 "Keylogging",
#                 "GUI Input Capture",
#                 "Web Portal Capture",
#                 "Credential API Hooking"
#             ]
#         },
#         "Screen Capture": {
#             "sub-techniques": []
#         },
#         "Video Capture": {
#             "sub-techniques": []
#         }
#     },
#     "Command and Control": {
#         "Application Layer Protocol": {
#             "sub-techniques": [
#                 "Web Protocols",
#                 "File Transfer Protocols",
#                 "Mail Protocols",
#                 "DNS"
#             ]
#         },
#         "Communication Through Removable Media": {
#             "sub-techniques": []
#         },
#         "Content Injection": {
#             "sub-techniques": []
#         },
#         "Data Encoding": {
#             "sub-techniques": [
#                 "Standard Encoding",
#                 "Non-Standard Encoding"
#             ]
#         },
#         "Data Obfuscation": {
#             "sub-techniques": [
#                 "Junk Data",
#                 "Steganography",
#                 "Protocol Impersonation"
#             ]
#         },
#         "Dynamic Resolution": {
#             "sub-techniques": [
#                 "Fast Flux DNS",
#                 "Domain Generation Algorithms",
#                 "DNS Calculation"
#             ]
#         },
#         "Encrypted Channel": {
#             "sub-techniques": [
#                 "Symmetric Cryptography",
#                 "Asymmetric Cryptography"
#             ]
#         },
#         "Fallback Channels": {
#             "sub-techniques": []
#         },
#         "Hide Infrastructure": {
#             "sub-techniques": []
#         },
#         "Ingress Tool Transfer": {
#             "sub-techniques": []
#         },
#         "Multi-Stage Channels": {
#             "sub-techniques": []
#         },
#         "Non-Application Layer Protocol": {
#             "sub-techniques": []
#         },
#         "Non-Standard Port": {
#             "sub-techniques": []
#         },
#         "Protocol Tunneling": {
#             "sub-techniques": []
#         },
#         "Proxy": {
#             "sub-techniques": [
#                 "Internal Proxy",
#                 "External Proxy",
#                 "Multi-hop Proxy",
#                 "Domain Fronting"
#             ]
#         },
#         "Remote Access Software": {
#             "sub-techniques": []
#         },
#         "Traffic Signaling": {
#             "sub-techniques": [
#                 "Port Knocking",
#                 "Socket Filters"
#             ]
#         },
#         "Web Service": {
#             "sub-techniques": [
#                 "Dead Drop Resolver",
#                 "Bidirectional Communication",
#                 "One-Way Communication"
#             ]
#         }
#     },
#     "Exfiltration": {
#         "Automated Exfiltration": {
#             "sub-techniques": [
#                 "Traffic Duplication"
#             ]
#         },
#         "Data Transfer Size Limits": {
#             "sub-techniques": []
#         },
#         "Exfiltration Over Alternative Protocol": {
#             "sub-techniques": [
#                 "Exfiltration Over Symmetric Encrypted Non-C2 Protocol",
#                 "Exfiltration Over Asymmetric Encrypted Non-C2 Protocol",
#                 "Exfiltration Over Unencrypted Non-C2 Protocol"
#             ]
#         },
#         "Exfiltration Over C2 Channel": {
#             "sub-techniques": []
#         },
#         "Exfiltration Over Other Network Medium": {
#             "sub-techniques": [
#                 "Exfiltration Over Bluetooth"
#             ]
#         },
#         "Exfiltration Over Physical Medium": {
#             "sub-techniques": [
#                 "Exfiltration over USB"
#             ]
#         },
#         "Exfiltration Over Web Service": {
#             "sub-techniques": [
#                 "Exfiltration to Code Repository",
#                 "Exfiltration to Cloud Storage",
#                 "Exfiltration to Text Storage Sites",
#                 "Exfiltration Over Webhook"
#             ]
#         },
#         "Scheduled Transfer": {
#             "sub-techniques": []
#         },
#         "Transfer Data to Cloud Account": {
#             "sub-techniques": []
#         }
#     },
#     "Impact": {
#         "Account Access Removal": {
#             "sub-techniques": []
#         },
#         "Data Destruction": {
#             "sub-techniques": []
#         },
#         "Data Encrypted for Impact": {
#             "sub-techniques": []
#         },
#         "Data Manipulation": {
#             "sub-techniques": [
#                 "Stored Data Manipulation",
#                 "Transmitted Data Manipulation",
#                 "Runtime Data Manipulation"
#             ]
#         },
#         "Defacement": {
#             "sub-techniques": [
#                 "Internal Defacement",
#                 "External Defacement"
#             ]
#         },
#         "Disk Wipe": {
#             "sub-techniques": [
#                 "Disk Content Wipe",
#                 "Disk Structure Wipe"
#             ]
#         },
#         "Endpoint Denial of Service": {
#             "sub-techniques": [
#                 "OS Exhaustion Flood",
#                 "Service Exhaustion Flood",
#                 "Application Exhaustion Flood",
#                 "Application or System Exploitation"
#             ]
#         },
#         "Financial Theft": {
#             "sub-techniques": []
#         },
#         "Firmware Corruption": {
#             "sub-techniques": []
#         },
#         "Inhibit System Recovery": {
#             "sub-techniques": []
#         },
#         "Network Denial of Service": {
#             "sub-techniques": [
#                 "Direct Network Flood",
#                 "Reflection Amplification"
#             ]
#         },
#         "Resource Hijacking": {
#             "sub-techniques": []
#         },
#         "Service Stop": {
#             "sub-techniques": []
#         },
#         "System Shutdown/Reboot": {
#             "sub-techniques": []
#         }
#     }
# }

# %%
def get_tactic_json(tactic_name):
    if tactic_name in final_json:
        return json.dumps(final_json[tactic_name], indent=4)
    else:
        return json.dumps({"error": f"No data found for tactic '{tactic_name}'"})

# %%
print(get_tactic_json('Persistence'))
# Out:
# {
#     "Account Manipulation": {
#         "sub-techniques": [
#             "Additional Cloud Credentials",
#             "Additional Email Delegate Permissions",
#             "Additional Cloud Roles",
#             "SSH Authorized Keys",
#             "Device Registration",
#             "Additional Container Cluster Roles"
#         ]
#     },
#     "BITS Jobs": {
#         "sub-techniques": []
#     },
#     "Boot or Logon Autostart Execution": {
#         "sub-techniques": [
#             "Registry Run Keys / Startup Folder",
#             "Authentication Package",
#             "Time Providers",
#             "Winlogon Helper DLL",
#             "Security Support Provider",
#             "Kernel Modules and Extensions",
#             "Re-opened Applications",
#             "LSASS Driver",
#             "Shortcut Modification",
#             "Port Monitors",
#             "Print Processors",
#             "XDG Autostart Entries",
#             "Active Setup",
#             "Login Items"
#         ]
#     },
#     "Boot or Logon Initialization Scripts": {
#         "sub-techniques": [
#             "Logon Script (Windows)",
#             "Login Hook",
#             "Network Logon Script",
#             "RC Scripts",
#             "Startup Items"
#         ]
#     },
#     "Browser Extensions": {
#         "sub-techniques": []
#     },
#     "Compromise Host Software Binary": {
#         "sub-techniques": []
#     },
#     "Create Account": {
#         "sub-techniques": [
#             "Local Account",
#             "Domain Account",
#             "Cloud Account"
#         ]
#     },
#     "Create or Modify System Process": {
#         "sub-techniques": [
#             "Launch Agent",
#             "Systemd Service",
#             "Windows Service",
#             "Launch Daemon",
#             "Container Service"
#         ]
#     },
#     "Event Triggered Execution": {
#         "sub-techniques": [
#             "Change Default File Association",
#             "Screensaver",
#             "Windows Management Instrumentation Event Subscription",
#             "Unix Shell Configuration Modification",
#             "Trap",
#             "LC_LOAD_DYLIB Addition",
#             "Netsh Helper DLL",
#             "Accessibility Features",
#             "AppCert DLLs",
#             "AppInit DLLs",
#             "Application Shimming",
#             "Image File Execution Options Injection",
#             "PowerShell Profile",
#             "Emond",
#             "Component Object Model Hijacking",
#             "Installer Packages"
#         ]
#     },
#     "External Remote Services": {
#         "sub-techniques": []
#     },
#     "Hijack Execution Flow": {
#         "sub-techniques": [
#             "DLL Search Order Hijacking",
#             "DLL Side-Loading",
#             "Dylib Hijacking",
#             "Executable Installer File Permissions Weakness",
#             "Dynamic Linker Hijacking",
#             "Path Interception by PATH Environment Variable",
#             "Path Interception by Search Order Hijacking",
#             "Path Interception by Unquoted Path",
#             "Services File Permissions Weakness",
#             "Services Registry Permissions Weakness",
#             "COR_PROFILER",
#             "KernelCallbackTable",
#             "AppDomainManager"
#         ]
#     },
#     "Implant Internal Image": {
#         "sub-techniques": []
#     },
#     "Modify Authentication Process": {
#         "sub-techniques": [
#             "Domain Controller Authentication",
#             "Password Filter DLL",
#             "Pluggable Authentication Modules",
#             "Network Device Authentication",
#             "Reversible Encryption",
#             "Multi-Factor Authentication",
#             "Hybrid Identity",
#             "Network Provider DLL",
#             "Conditional Access Policies"
#         ]
#     },
#     "Office Application Startup": {
#         "sub-techniques": [
#             "Office Template Macros",
#             "Office Test",
#             "Outlook Forms",
#             "Outlook Home Page",
#             "Outlook Rules",
#             "Add-ins"
#         ]
#     },
#     "Power Settings": {
#         "sub-techniques": []
#     },
#     "Pre-OS Boot": {
#         "sub-techniques": [
#             "System Firmware",
#             "Component Firmware",
#             "Bootkit",
#             "ROMMONkit",
#             "TFTP Boot"
#         ]
#     },
#     "Scheduled Task/Job": {
#         "sub-techniques": [
#             "At",
#             "Cron",
#             "Scheduled Task",
#             "Systemd Timers",
#             "Container Orchestration Job"
#         ]
#     },
#     "Server Software Component": {
#         "sub-techniques": [
#             "SQL Stored Procedures",
#             "Transport Agent",
#             "Web Shell",
#             "IIS Components",
#             "Terminal Services DLL"
#         ]
#     },
#     "Traffic Signaling": {
#         "sub-techniques": [
#             "Port Knocking",
#             "Socket Filters"
#         ]
#     },
#     "Valid Accounts": {
#         "sub-techniques": [
#             "Default Accounts",
#             "Domain Accounts",
#             "Local Accounts",
#             "Cloud Accounts"
#         ]
#     }
# }

# %%
def get_technique_json(technique_name):
    tactic_found = []
    sub_techniques = []

    for tactic, techniques in final_json.items():
        if technique_name in techniques:
            tactic_found.append(tactic)
            sub_techniques = techniques[technique_name].get('sub-techniques', [])

    if tactic_found:
        response = {
            "Technique": technique_name,
            "Tactics": tactic_found,
            "Sub-techniques": sub_techniques
        }
        return json.dumps(response, indent=4)
    else:
        return json.dumps({"error": f"No data found for technique '{technique_name}'"})

# %%
print(get_technique_json('Scheduled Task/Job'))
# Out:
# {
#     "Technique": "Scheduled Task/Job",
#     "Tactics": [
#         "Execution",
#         "Persistence",
#         "Privilege Escalation"
#     ],
#     "Sub-techniques": [
#         "At",
#         "Cron",
#         "Scheduled Task",
#         "Systemd Timers",
#         "Container Orchestration Job"
#     ]
# }
